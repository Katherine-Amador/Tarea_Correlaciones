# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
wh = pd.read_csv('2018.csv')

# %%
wh
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
wh.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
wh.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
columns_to_use=['Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']

# %%
corr_use=wh.loc[: , columns_to_use].corr()

# %%
corr_use
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.802124        0.745760
# GDP per capita                0.802124        1.000000        0.672080
# Social support                0.745760        0.672080        1.000000
# Healthy life expectancy       0.775814        0.844273        0.667288
# Freedom to make life choices  0.544280        0.332275        0.411087
# Generosity                    0.135825       -0.011241        0.018226
# Perceptions of corruption     0.405292        0.319582        0.218364
#
#                               Healthy life expectancy  \
# Score                                        0.775814
# GDP per capita                               0.844273
# Social support                               0.667288
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.355475
# Generosity                                   0.020751
# ...

# %%
plt.matshow(corr_use)

# %%
f, ax = plt.subplots(figsize=(10,8))

sns.heatmap(corr_use, mask=np.zeros_like(corr_use, dtype=np.bool), cmap=sns.diverging_palette(280, 50,  as_cmap=True),
           square=True, ax=ax)
# Out:
# <ipython-input-36-c0252280f06c>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr_use, mask=np.zeros_like(corr_use, dtype=np.bool), cmap=sns.diverging_palette(280, 50,  as_cmap=True),
# <AxesSubplot:>

# %% [markdown]
# Conclusiones:
# 1. Los cuadros de color café oscuro representan una correlación positiva.
# 2. Hay un unico valor negativo que tiende a ser cero y esto se da entre la columna Generosity y GDA per capita, se puede observar que es de un tono morado oscuro.
# 3. Varios valores tienden a acercarse a uno como lo podemos observar en la columna Score y GDA per capita. Son variables altamente correcionables.
# 4. Podemos observar que tenemos una posible correlación entre las variables de Healty life expectancy y GDP per capita.

# %% [markdown]
# Casualidad:
# 1. Si tenemos un social support tendemos a no prestar atención o no tener una Perceptions of corruption.
# 2. GDP per capita nos conlleva a tener un Healthy life expectancy
# 3. Cuando se obtiene un Social support se tiende a tener Healthy life expectancy.
